# %%
import cv2
import numpy as np
import random
import os
import mediapipe as mp
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from matplotlib.colors import LinearSegmentedColormap

# %%
# Define constants
IMAGE_SIZE = (224, 224)  # Size to which images will be resized
BATCH_SIZE = 32          # Number of samples per gradient update
EPOCHS = 400             # Number of epochs to train the model
INPUT_SHAPE = (33 * 4,)  # Shape of the input data (pose keypoints)

# %%
# Initialize data lists and Mediapipe Pose
data = []
labels = []
pose = mp.solutions.pose.Pose()

# %%
# Function to rotate an image by a given angle
def rotate_image(image, angle):
    rows, cols, _ = image.shape
    rotation_matrix = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (cols, rows))
    return rotated_image

# %%
# Function to adjust image brightness
def add_brightness(image, brightness):
    adjusted_image = np.clip(image + brightness, 0, 255).astype(np.uint8)
    return adjusted_image

# %%
# Function to preprocess images from a directory and assign them a label
def preprocess_images(directory, label):
    for filename in os.listdir(directory):
        image_path = os.path.join(directory, filename)
        image = cv2.imread(image_path)
        if image is None:
            continue

        # Convert image to RGB format
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Create augmented versions of the image
        augmented_images = [
            image,
            rotate_image(image, 20),
            cv2.flip(image, 0),
            cv2.resize(image, IMAGE_SIZE),
            add_brightness(image, random.randint(20, 70))
        ]

        # Process each augmented image to extract pose keypoints
        for img in augmented_images:
            results = pose.process(img)
            if results.pose_landmarks:
                # Extract and flatten pose keypoints
                pose_keypoints = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
                data.append(pose_keypoints)
                labels.append(label)

# %%
# Preprocess data for both classes (0 and 1)
preprocess_images(r'Test\1', 1)
preprocess_images(r'Test\0', 0)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(np.array(data), np.array(labels), test_size=0.3, random_state=42)

# %%
# Function to build the neural network model
def build_model(input_shape):
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(BatchNormalization())  # Batch normalization before activation
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # Increase dropout rate
    model.add(BatchNormalization())  # Batch normalization before activation
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))  # Increase dropout rate
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# Build and compile the model
model = build_model(INPUT_SHAPE)
# Out:
# C:\Users\Marley Amged\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Define early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# %%
# Train the model
Data_history=model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping], validation_data=(X_test, y_test))
# Out:
# Epoch 1/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5335 - loss: 0.8241 - val_accuracy: 0.6260 - val_loss: 0.6421
# Epoch 2/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6364 - loss: 0.6608 - val_accuracy: 0.6179 - val_loss: 0.6682
# Epoch 3/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7970 - loss: 0.4309 - val_accuracy: 0.6179 - val_loss: 0.7361
# Epoch 4/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7907 - loss: 0.4560 - val_accuracy: 0.6179 - val_loss: 0.7940
# Epoch 5/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8707 - loss: 0.3468 - val_accuracy: 0.6179 - val_loss: 0.8366
# Epoch 6/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9122 - loss: 0.2886 - val_accuracy: 0.6179 - val_loss: 0.8683
# Epoch 7/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8178 - loss: 0.3539 - val_accuracy: 0.6179 - val_loss: 0.8927
# Epoch 8/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8564 - loss: 0.2861 - val_accuracy: 0.6179 - val_loss: 0.9191
# Epoch 9/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8675 - loss: 0.2698 - val_accuracy: 0.6179 - val_loss: 0.9242
# Epoch 10/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.0456 - val_accuracy: 1.0000 - val_loss: 0.0232
# Epoch 136/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9919 - val_loss: 0.0286
# Epoch 137/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9939 - loss: 0.0166 - val_accuracy: 0.9837 - val_loss: 0.0428
# Epoch 138/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9901 - loss: 0.0222 - val_accuracy: 0.9837 - val_loss: 0.0485
# Epoch 139/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.0455 - val_accuracy: 0.9756 - val_loss: 0.0516
# Epoch 140/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9780 - loss: 0.0783 - val_accuracy: 0.9593 - val_loss: 0.0669
# Epoch 141/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9823 - loss: 0.0467 - val_accuracy: 0.9675 - val_loss: 0.0622
# Epoch 142/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9933 - loss: 0.0187 - val_accuracy: 0.9837 - val_loss: 0.0514
# Epoch 143/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0099 - val_accuracy: 0.9837 - val_loss: 0.0499
# Epoch 144/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9952 - loss: 0.0191 - val_accuracy: 0.9837 - val_loss: 0.0472
# Epoch 145/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9837 - val_loss: 0.0456
# Epoch 146/400
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9908 - loss: 0.0334 - val_accuracy: 0.9837 - val_loss: 0.0531

# %%
plt.plot(Data_history.history['loss'], label='Train Loss')
plt.plot(Data_history.history['val_loss'], label='Test Loss')

plt.show()
plt.plot(Data_history.history['accuracy'], label='Train Accuracy')
plt.plot(Data_history.history['val_accuracy'], label='Test Accuracy')

plt.show()

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0777
# Test Accuracy: 98.37%

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 132)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 132)                 │             528 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          17,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 78,117 (305.15 KB)
#  Trainable params: 25,865 (101.04 KB)
#  Non-trainable params: 520 (2.03 KB)
#  Optimizer params: 51,732 (202.08 KB)

# %%
model.save('coachmodel.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.load_weights('coachmodel.h5')

# %%
# Predictions and analysis
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(classification_report(y_test, y_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        47
#            1       1.00      0.97      0.99        76
#
#     accuracy                           0.98       123
#    macro avg       0.98      0.99      0.98       123
# weighted avg       0.98      0.98      0.98       123

# %%
def confusion_matrix(model, test, labels):
    y_pred = model.predict(test)
    y_pred = np.round(y_pred)

    cm = metrics.confusion_matrix(labels, y_pred)
    
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[False, True])
    
    # Create a custom black and white colormap
    colors = [(0, 0, 0), (1, 1, 1)]  # RGB for black and white
    cmap_name = 'black_white'
    custom_cmap = LinearSegmentedColormap.from_list(cmap_name, colors)
    
    # Plot the confusion matrix with the custom colormap
    fig, ax = plt.subplots()
    cm_display.plot(ax=ax, cmap=custom_cmap)
    
    plt.show()

# %%
confusion_matrix(model,np.array(data),np.array(labels))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
BOLD = "\033[1m"
END = "\033[0m"
GREEN = "\033[92m"
RED = "\033[91m"

# Print "P: Correct" in green and bold
print(f"{BOLD}{GREEN}P: Correct{END}")

# Print "T: Incorrect" in red and bold
print(f"{BOLD}{RED}T: Incorrect{END}")

Photo=cv2.imread(r'Test\0\Sideplank6.jpg')
photo_rgb = cv2.cvtColor(Photo, cv2.COLOR_BGR2RGB)
plt.imshow(photo_rgb)
# Out:
# P: Correct
# T: Incorrect
